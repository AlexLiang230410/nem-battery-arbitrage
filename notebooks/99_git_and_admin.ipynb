# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexLiang230410/nem-battery-arbitrage/blob/main/notebooks/99_git_and_admin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Start of day cell

# %%
import os

# Run this once to set your Git identity in the Colab environment
# !git config user.name "Alex Liang"
# !git config user.email "your_email@example.com"

GITHUB_USER = "AlexLiang230410"
REPO_NAME = "nem-battery-arbitrage"
REPO_URL = f"https://github.com/{GITHUB_USER}/{REPO_NAME}.git"
# Clone the repo only if it does not exist yet
if not os.path.exists(f"/content/{REPO_NAME}"):
    # !git clone {REPO_URL}
# Change working directory to the project root
os.chdir(f"/content/{REPO_NAME}")
print("Current working directory:", os.getcwd())
# !ls
# Out:
# Current working directory: /content/nem-battery-arbitrage
# battery_core.py  data  data_utils.py  notebooks  __pycache__  README.md

# %% [markdown]
# 2. End of day – Step 1: check status

# %%
import os

os.chdir("/content/nem-battery-arbitrage")
print("Current working directory:", os.getcwd())
# !git status
# Out:
# Current working directory: /content/nem-battery-arbitrage
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   __pycache__/battery_core.cpython-312.pyc

# %% [markdown]
# 3. End of day – Step 2: add ALL changes and commit

# %%
import os
os.chdir("/content/nem-battery-arbitrage")
# Stage all modified, new and deleted files
# !git add -A
# Double-check what will be committed
# !git status
# Commit with a short message (edit this string each day)
COMMIT_MESSAGE = "Update code and notebooks"
# !git commit -m "{COMMIT_MESSAGE}"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   __pycache__/battery_core.cpython-312.pyc
#
# [main 9b5ef71] Update code and notebooks
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 __pycache__/battery_core.cpython-312.pyc

# %% [markdown]
# 4. End of day – Step 3: push safely with hidden PAT

# %%
from getpass import getpass
import os
os.chdir("/content/nem-battery-arbitrage")
GITHUB_USER = "AlexLiang230410"
REPO_NAME = "nem-battery-arbitrage"
# Enter your GitHub Personal Access Token here.
# The input will NOT be shown in the notebook.
token = getpass("Enter your GitHub PAT (input is hidden): ")
push_url = f"https://{GITHUB_USER}:{token}@github.com/{GITHUB_USER}/{REPO_NAME}.git"

# !git push {push_url} main
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1361933495.py in <cell line: 0>()
#       7 REPO_NAME = "nem-battery-arbitrage"
#       8
# ----> 9 TOKEN = getpass("ghp_xxx: ")
#      10
#      11 PUSH_URL = f"https://{GITHUB_USER}:{TOKEN}@github.com/{GITHUB_USER}/{REPO_NAME}.git"
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#    1157                 stacklevel=2,
#    1158             )
# -> 1159         return self._input_request(
#    1160             prompt,
#    1161             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...
